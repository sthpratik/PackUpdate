# %%
from packUpdate import run_update_process
run_update_process('/Users/manshres1/Documents/Apps/rosetta-fusion', '--safe', 1)
# Out:
# === Pass 1 ===
#
# Outdated Packages:
# Package                                  Current    Wanted     Latest
# ----------------------------------------------------------------------
# @epsilon/alderaan                        2.1.2      2.1.2      3.1.0
# @epsilon/massiff                         1.0.0      1.0.0      1.1.0
# @types/chai                              4.2.22     4.2.22     5.2.1
# @types/express                           4.17.21    4.17.21    5.0.1
# @typescript-eslint/eslint-plugin         6.4.1      6.4.1      8.29.0
# @typescript-eslint/parser                6.4.1      6.4.1      8.29.0
# chai                                     4.3.10     4.3.10     5.2.0
# chai-http                                4.4.0      4.4.0      5.1.1
# eslint                                   8.47.0     8.47.0     9.23.0
# eslint-config-prettier                   9.0.0      9.0.0      10.1.1
# eslint-plugin-prettier                   5.0.1      5.0.1      5.2.5
# ...
